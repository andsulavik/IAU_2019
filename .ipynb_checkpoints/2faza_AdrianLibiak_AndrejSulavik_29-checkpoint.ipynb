# %% [markdown]
# <h1>2. fáza - predspracovanie dát</h1>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.preprocessing import Imputer
from sklearn import linear_model

import re

percentil5 = []
percentil95 = []

imp = Imputer(missing_values='NaN', strategy='median')

linearKurtOx = linear_model.LinearRegression()
linearMeanGlu = linear_model.LinearRegression()
# Out:
# C:\Users\adria\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
def splitPersonalInfo(dataO):
    temp = dataO['personal_info'].str.split("\r\r\n|--|\\|", expand = True)
    dataO['ethn'] = temp[0]
    dataO['state'] = temp[1]
    dataO['edu'] = temp[2]
    dataO['status'] = temp[3]
    dataO['fam_memb'] = temp[4] 
    dataO.drop(['personal_info'], axis = 1, inplace = True)

# %%
def fusionDuplicates(datasetO):
    duplicat = datasetO[datasetO['name'].duplicated(keep=False)]
    duplicat = duplicat.sort_values('name')
    duplicat = duplicat.reset_index(drop=True)
    
    for i, row in duplicat.iterrows():
        if(i%2==1):
            duplicat = duplicat.drop(i)
            continue
        for j, value in row.items():
            dupValue = duplicat.loc[i+1,j]
            if(pd.isna(value)):
                duplicat.loc[i,j]=dupValue
    datasetO.drop_duplicates(subset='name',keep=False,inplace=True)
    result = datasetO.append(duplicat, ignore_index=True)
    return(result)

# %%
def correctValuesO(dataset):
    for col in dataset.columns:
        if(dataset[col].dtype != np.object):
            continue
        dataset[col] = dataset[col].str.replace('_','-')
        dataset[col] = dataset[col].replace(to_replace = r'.*\?.*', value = np.nan, regex = True)
        dataset[col] = dataset[col].replace(to_replace = r'^[Nn][Aa][Nn]$', value = np.nan, regex = True)
        if(col=='pregnant'):
            dataset[col] = dataset[col].replace(['T','F'], ['t', 'f'])
            dataset[col] = dataset[col].replace(to_replace = r'[Tt][Rr][Uu][Ee]', value = 't', regex = True)
            dataset[col] = dataset[col].replace(to_replace = r'[Ff][Aa][Ll][Ss][Ee]', value = 'f', regex = True)

def correctDates(series):
    s = series.str.split("-", expand = True)
    x = 0
    while(x<len(series)):
#        print(str(x)+" "+s.iloc[x])
        if(re.match(r'^[0-9][0-9]-[0-9][0-9]-[0-9][0-9]$', series.loc[x])):
            if(s.iloc[x][0][:1]=='0'):
                series.loc[x] = "20"+s.iloc[x][0]+"-"+s.iloc[x][1]+"-"+s.iloc[x][2][0:2]
            else:
                series.loc[x] = "19"+s.iloc[x][0]+"-"+s.iloc[x][1]+"-"+s.iloc[x][2][0:2]
#            x += 1
#            continue
         #if(len(s.iloc[x][2])>2):
         #   series.loc[x] = s.iloc[x][0]+"-"+s.iloc[x][1]+"-"+s.iloc[x][2][:2]
        if(re.match(r'^[0-9][0-9]-[0-9][0-9]-[0-9][0-9][0-9][0-9]$', series.loc[x])):
            y = s.iloc[x][0]
            s.iloc[x][0] = s.iloc[x][2]
            s.iloc[x][2] = y
            series.loc[x] = s.iloc[x][0]+"-"+s.iloc[x][1]+"-"+s.iloc[x][2][0:2]
        if(len(series.loc[x])>10):
            series.loc[x] = series.loc[x][0:10]
        x += 1
        
def correctValuesP(dataset):
    for col in dataset.columns:
        if(dataset[col].dtype != np.object):
            continue
        dataset[col] = dataset[col].str.replace('/','-')    
    correctDates(dataset["date_of_birth"])

# %%
def fusionDatasets(dataset1, dataset2):
    newDS = dataset1.merge(dataset2, on='name')
    newDS = newDS.drop(columns=['name', 'address_x', 'address_y'])
    return newDS

# %%
def correctAge(dataF):
    x = 0
    for x in range(len(dataF)):
        #print(x)
        s = dataF['date_of_birth'].iloc[x].split('-', 2)
        year = s[0]
        #116 najstarsi clovek v sucastnosti
        if(dataF['age'].iloc[x]>116):
            age = dataF['age'].iloc[x]/100
            if((2019-int(age) == int(year) or (2019-int(age) == int(year)+1))):
                dataF['age'].iloc[x] =  int(age);
                continue
            else:
                print("ERROR  "+str(age)+"  "+str(int(year)))
        elif(dataF['age'].iloc[x]<-116):
            age = dataF['age'].iloc[x]/(-100)
            if(2019-int(age) == int(year) or 2019-int(age) == int(year)+1):
                dataF['age'].iloc[x] =  int(age);
                continue
            else:
                print("ERROR  "+str(age)+"  "+str(int(year)))
        else:
            age = 2019 - int(year)
            if(age<=0):
                dataF['age'].iloc[x] = np.nan
            else:
                dataF['age'].iloc[x] =  int(age);

# %%
def detectReplaceOutliers(dataF):
    for col in dataF.columns:
        if(dataF[col].dtype == np.object):
            continue
        if(col == 'capital-loss' or col == 'capital-gain' or col == 'age'):
            continue
        if(col != 'std_glucose' and col != 'fnlwgt' and col != 'mean_glucose' and col != 'hours-per-week'):
            dataF.loc[:,col] = dataF[col].apply(lambda x: -2.5 if x<-2.5 else x)
            dataF.loc[:,col] = pd.Series(np.log(dataF[col]+2.5))
        percentil5.append(dataF[col].quantile(0.05))
        percentil95.append(dataF[col].quantile(0.95))
        p5 = percentil5[-1]
        p95 = percentil95[-1]
        print(col+" q0.05: "+str(p5))
        print(col+" q0.95: "+str(p95))
        dataF.loc[:,col] = dataF[col].apply(lambda x: p5 if x<p5 else x)
        dataF.loc[:,col] = dataF[col].apply(lambda x: p95 if x>p95 else x)

# %% [markdown]
# Z predchádzajúcej analýzy sme zistili, že stlpce std_glucose, fnlwgt, mean_glucose, hours-per-week majú približne normalné rozdelenie a ostatné stľpce bude potrebné transformovať pomocou logaritmu. Ten nemôže byť zo záporného čísla, preto použijeme minimálnu hodnotu z analýzi (-1.976976) a k dátam bude pre istotu prirítané 2,5. Zároveň aj ošetríme aby ani v testovacých dátach nebola nižšia hodnota tak, že všetky nižšie prestavíme na túto hodnotu.

# %%
def transformDetectReplaceOutliers(dataF):
    i = 0
    for col in dataF.columns:
        if(dataF[col].dtype == np.object):
            continue
        if(col == 'capital-loss' or col == 'capital-gain' or col == 'age'):
            continue
        if(col != 'std_glucose' and col != 'fnlwgt' and col != 'mean_glucose' and col != 'hours-per-week'):
            dataF.loc[:,col] = dataF[col].apply(lambda x: -2.5 if x<-2.5 else x)
            dataF.loc[:,col] = pd.Series(np.log(dataF[col]+2.5))
        p5 = percentil5[i]
        p95 = percentil95[i]
        i=i+1
        print(col+" q0.05: "+str(p5))
        print(col+" q0.95: "+str(p95))
        dataF.loc[:,col] = dataF[col].apply(lambda x: p5 if x<p5 else x)
        dataF.loc[:,col] = dataF[col].apply(lambda x: p95 if x>p95 else x)

# %%
def impMedianFit(dataF):
    imp.fit(dataF[["age","skewness_glucose","std_oxygen", "capital-gain", "skewness_oxygen", "kurtosis_glucose", "fnlwgt", "std_glucose", "mean_oxygen", "hours-per-week", "capital-loss"]])
    
def impMedianTransform(dataF):
    dataF[["age","skewness_glucose","std_oxygen", "capital-gain", "skewness_oxygen", "kurtosis_glucose", "fnlwgt", "std_glucose", "mean_oxygen", "hours-per-week", "capital-loss"]] = imp.transform(dataF[["age","skewness_glucose","std_oxygen", "capital-gain", "skewness_oxygen", "kurtosis_glucose", "fnlwgt", "std_glucose", "mean_oxygen", "hours-per-week", "capital-loss"]])

# %%
def linearFit(dataF):
    dataToFit = dataF[~dataF["kurtosis_oxygen"].isnull()]
    linearKurtOx.fit(X = dataToFit[["skewness_oxygen","mean_oxygen"]], y = dataF["kurtosis_oxygen"].dropna())
    dataToFit = dataF[~dataF["mean_glucose"].isnull()]
    linearMeanGlu.fit(X = dataToFit[["skewness_glucose", "kurtosis_glucose"]], y = dataF["mean_glucose"].dropna())
def linearTransform(dataF):
    dataF.loc[dataF["kurtosis_oxygen"].isnull(), "kurtosis_oxygen"] = linearKurtOx.predict(dataF[["skewness_oxygen","mean_oxygen"]])[dataF["kurtosis_oxygen"].isnull()]
    dataF.loc[dataF["mean_glucose"].isnull(), "mean_glucose"] = linearMeanGlu.predict(dataF[["skewness_glucose", "kurtosis_glucose"]])[dataF["mean_glucose"].isnull()]

# %%
def setKategNaNtoUnknown(dataF):
    for col in dataF.columns:
        if(dataF[col].dtype != np.object):
            continue
        dataF[col].replace(to_replace=np.nan, value='unknown', inplace = True)

# %%
def finalFitAndTransform(dataP,dataO):
    print('spliting personal info')
    splitPersonalInfo(dataO)
    print('deduplicating names')
    dataO=fusionDuplicates(dataO)
    print('correcting O values')
    correctValuesO(dataO)
    print('correcting P values')
    correctValuesP(dataP)
    print('merging datasets')
    dataF = fusionDatasets(dataP, dataO)
    dataF = dataF.astype({'class':str,"education-num":str,"kurtosis_oxygen":float})
    
    print('correcting age')
    correctAge(dataF)
    print('correcting outliers')
    detectReplaceOutliers(dataF)
    
    setKategNaNtoUnknown(dataF)
    print('filling missing values with median')
    impMedianFit(dataF)
    impMedianTransform(dataF)
    print('filling missing values with linear regression')
    linearFit(dataF)
    linearTransform(dataF)
    return dataF

# %%
def finalTransform(dataP,dataO):
    print('correcting values')
    splitPersonalInfo(dataO)
    dataO=fusionDuplicates(dataO)
    correctValuesO(dataO)
    correctValuesP(dataP)
    dataF = fusionDatasets(dataP, dataO)
    dataF = dataF.astype({'class':str,"education-num":str,"kurtosis_oxygen":float})
    print('working with outliers')
    correctAge(dataF)
    transformDetectReplaceOutliers(dataF)
    print('filling missing values')
    setKategNaNtoUnknown(dataF)
    impMedianTransform(dataF)
    linearTransform(dataF)
    return dataF

# %%
dataP = pd.read_csv("personal_train.csv", index_col=0)
dataO = pd.read_csv("other_train.csv", index_col=0)

# %%
splitPersonalInfo(dataO)

# %% [markdown]
# Zozdelenie stípca personal info z analýzy.

# %%
dataP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3933 entries, 0 to 3932
# Data columns (total 5 columns):
# name             3933 non-null object
# address          3933 non-null object
# age              3933 non-null int64
# sex              3933 non-null object
# date_of_birth    3933 non-null object
# dtypes: int64(1), object(4)
# memory usage: 184.4+ KB

# %%
dataO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3983 entries, 0 to 3982
# Data columns (total 25 columns):
# name                3983 non-null object
# address             3983 non-null object
# kurtosis_oxygen     3709 non-null object
# occupation          3974 non-null object
# pregnant            3967 non-null object
# education-num       3964 non-null float64
# skewness_glucose    3970 non-null float64
# mean_glucose        3573 non-null float64
# std_oxygen          3967 non-null float64
# capital-gain        3970 non-null float64
# skewness_oxygen     3969 non-null float64
# kurtosis_glucose    3965 non-null float64
# fnlwgt              3974 non-null float64
# class               3972 non-null float64
# std_glucose         3964 non-null float64
# income              3967 non-null object
# mean_oxygen         3971 non-null float64
# hours-per-week      3969 non-null float64
# capital-loss        3971 non-null float64
# workclass           3961 non-null object
# ethn                3968 non-null object
# state               3968 non-null object
# edu                 3968 non-null object
# status              3968 non-null object
# fam_memb            3968 non-null object
# dtypes: float64(13), object(12)
# memory usage: 809.0+ KB

# %%
len(dataO.name.unique())
# Out:
# 3933

# %%
namesO = dataO["name"].unique().sort()

# %%
namesP = dataP["name"].unique().sort()

# %%
np.array_equal(namesO, namesP)
# Out:
# True

# %% [markdown]
# Zistili sme, že mená v obydvoch datasetochsú rovnaké, preto odstraníme duplicitn mená z datasetu other.

# %%
duplNames = dataO[dataO['name'].duplicated(keep=False)]
duplNames.sort_values('name')
# Out:
#                    name                                            address  \
# 3718      Andrew Lawson  57159 Christopher Throughway Apt. 388\r\nWest ...
# 1298      Andrew Lawson  57159 Christopher Throughway Apt. 388\r\nWest ...
# 3402    Andrew Olmstead  519 Christopher Loop Suite 282\r\nRachelside, ...
# 281     Andrew Olmstead  519 Christopher Loop Suite 282\r\nRachelside, ...
# 3851     Antonio Bailey        29028 Bowman Parkways\r\nKerrview, FL 57851
# 2222     Antonio Bailey        29028 Bowman Parkways\r\nKerrview, FL 57851
# 2606      Antonio Rowan  016 Jacob Tunnel Apt. 031\r\nAmandabury, CA 37683
# 1987      Antonio Rowan  016 Jacob Tunnel Apt. 031\r\nAmandabury, CA 37683
# 3947         Ben Nelson        45315 Obrien Inlet\r\nCynthiaport, OH 63603
# 956          Ben Nelson        45315 Obrien Inlet\r\nCynthiaport, OH 63603
# 3274    Charles Pollack  5703 Wilson Union Apt. 105\r\nStevenhaven, NJ ...
# 3024    Charles Pollack  5703 Wilson Union Apt. 105\r\nStevenhaven, NJ ...
# 918       Craig Solomon                 PSC 7142, Box 7999\r\nAPO AA 51659
# 6         Craig Solomon                 PSC 7142, Box 7999\r\nAPO AA 51659
# 2340      David Arebalo          0519 Cassie Orchard\r\nNew John, TX 71955
# 2474     William Glover  655 Cody River Suite 554\r\nNorth Colton, DC 2...
# 2372     William Glover  655 Cody River Suite 554\r\nNorth Colton, DC 2...
# 2423      William Hicks  66744 Tiffany Shores Apt. 950\r\nNew Timothy, ...
# 1683      William Hicks  66744 Tiffany Shores Apt. 950\r\nNew Timothy, ...
# 2575     William Joecks  089 Sherry Hollow Suite 058\r\nBrianberg, CT 0...
# 2280     William Joecks  089 Sherry Hollow Suite 058\r\nBrianberg, CT 0...
# 2259      William Stone  535 Cabrera Wall Apt. 927\r\nEast David, TX 70904
# 1236      William Stone  535 Cabrera Wall Apt. 927\r\nEast David, TX 70904
#
#          kurtosis_oxygen          occupation pregnant  education-num  \
# 3718         10.56049223                 NaN        f            NaN
# 1298         10.56049223               Sales        f           13.0
# 3402  6.9289193560000015        Craft-repair        f            9.0
# 281   6.9289193560000015                 NaN        f            NaN
# 3851         0.368701087               Sales        f            6.0
# 2222         0.368701087               Sales      NaN            NaN
# 2606                  ??   Handlers-cleaners        f            9.0
# 1987                  ??   Handlers-cleaners      NaN            9.0
# 3947         22.14937084    Transport-moving        f            9.0
# 956          22.14937084    Transport-moving        f            9.0
# 3274  2.3511303530000003     Exec-managerial        t           11.0
# 3024  2.3511303530000003     Exec-managerial        t            NaN
# 918    9.046560192000001               Sales        f           10.0
# 6      9.046560192000001               Sales        f           10.0
# 2340          1.28418567     Exec-managerial        f           10.0
# 1791          1.28418567     Exec-managerial        f            NaN
# 636          8.815196362      Prof-specialty      NaN           14.0
# 1813         8.815196362      Prof-specialty        f           14.0
# 3878                 NaN      Prof-specialty        f           14.0
# 477                  NaN      Prof-specialty      NaN           14.0
# 3241                 NaN               Sales    FALSE            NaN
# 174                  NaN               Sales    FALSE            9.0
# 514          2.961762332     Exec-managerial        f           13.0
# 2984         2.961762332     Exec-managerial        f           13.0
# 2540         15.88535622     Farming-fishing        f            9.0
# 1277         15.88535622     Farming-fishing      NaN            9.0
# 3204         8.108129205    Transport-moving      NaN            NaN
# 2779         8.108129205    Transport-moving        f            9.0
# 294          4.847933096     Exec-managerial        f            9.0
# 3010         4.847933096     Exec-managerial        f            9.0
# ...                  ...                 ...      ...            ...
# 2267                 NaN               Sales      NaN           13.0
# 2201                 NaN               Sales        f           13.0
# 2976         12.28357567    Transport-moving        f            5.0
# 1554                 NaN    Transport-moving        f            NaN
# 3634         6.062392209               Sales        f            9.0
# 84           6.062392209               Sales        f            9.0
# 3441         6.773794869               Sales        f            NaN
# 124          6.773794869               Sales        f           10.0
# 1856         8.074870162        Craft_repair        f            NaN
# 3162         8.074870162        Craft_repair        f            9.0
# 826    8.466196457999999       Other-service        f            9.0
# 3785   8.466196457999999       Other-service        f            9.0
# 1961          0.48443973               Sales        f           13.0
# 1874          0.48443973               Sales        f           13.0
# 2159         7.151723994      Prof-specialty    FALSE            NaN
# 1241         7.151723994                 NaN    FALSE           14.0
# 2978         6.633057813      Prof-specialty      NaN           14.0
# 2999       ...          >50K     1.147993            40.0           0.0
# 3077       ...          >50K     1.147993            40.0           NaN
# 2818       ...         <=50K          NaN            15.0           0.0
# 3480       ...         <=50K     1.607860            15.0           0.0
# 2474       ...         <=50K     1.458194            40.0           0.0
# 2372       ...         <=50K     1.458194            40.0           0.0
# 2423       ...         <=50K    26.705686            40.0           0.0
# 1683       ...         <=50K    26.705686            40.0           0.0
# 2575       ...         <=50K          NaN            15.0           0.0
# 2280       ...         <=50K    79.782609             NaN           0.0
# 2259       ...           NaN     6.880435            35.0           0.0
# 1236       ...         <=50K     6.880435            35.0           0.0
#
#               workclass                ethn          state            edu  \
# 3718                NaN               White  United-States     Bachelors
# 1298            Private               White  United-States     Bachelors
# 3402                NaN               White  United-States       HS-grad
# 281             Private               White  United-States       HS-grad
# 3851       Self-emp-inc               White         Canada          10th
# 2222       Self-emp-inc               White         Canada          10th
# 2606            Private                 NaN            NaN            NaN
# 1987            Private               Black  United-States       HS-grad
# 3947            Private               White  United-States       HS-grad
# 956             Private                 NaN            NaN            NaN
# 3274            Private               White  United-States     Assoc-voc
# 3024            Private               White  United-States     Assoc-voc
# 918                 NaN               White  United-States  Some-college
# 6               Private               White  United-States  Some-college
# 2340            Private               White  United-States  Some-college
# 1791            Private               White  United-States  Some-college
# 636           Local-gov               White  United-States       Masters
# 1813          Local-gov               White  United-States       Masters
# 3878   Self-emp-not-inc               White              ?       Masters
# 477    Self-emp-not-inc                 NaN            NaN            NaN
# 3241            Private                 NaN            NaN            NaN
# 174             Private               White  United-States       HS-grad
# 514             Private  Asian-Pac-Islander    Philippines     Bachelors
# 2984            Private  Asian-Pac-Islander    Philippines     Bachelors
# 2540          Local-gov               White  United-States       HS-grad
# 1277          Local-gov                 NaN            NaN            NaN
# 3204            Private               White  United-States       HS-grad
# 2779            Private               White  United-States       HS-grad
# 294           Local-gov               White  United-States       HS-grad
# 3010                NaN               White  United-States       HS-grad
# ...                 ...                 ...            ...            ...
# 2267            Private               Black  United-States     Bachelors
# 2201                NaN               Black  United-States     Bachelors
# 2976   Self-emp-not-inc               White  United-States           9th
# 1554   Self-emp-not-inc               White  United-States           9th
# 3634                NaN               White  United-States       HS-grad
# 84              Private               White  United-States       HS-grad
# 3441            Private                 NaN            NaN            NaN
# 124             Private               White  United-States  Some-college
# 1856   Self-emp-not-inc               White  United-States       HS-grad
# 3162   Self-emp-not-inc               White  United-States       HS-grad
# 826             Private               White  United-States       HS-grad
# 3785                NaN               White  United-States       HS-grad
# 1961            Private               White  United-States     Bachelors
# 1874            Private               White  United-States     Bachelors
# 2159            Private               White  United-States       Masters
# 1241                NaN                 NaN            NaN            NaN
# 2978                NaN               White  United-States       Masters
# 1921          State-gov               White  United-States       Masters
# 2999            Private               White  United-States     Bachelors
# 3077            Private               White  United-States     Bachelors
# 2818            Private               White  United-States          11th
# 3480            Private               White  United-States          11th
# 2474                NaN               White  United-States       HS-grad
# 2372                NaN               White  United-States       HS-grad
# 2423        Federal-gov               White  United-States       Masters
# 1683                NaN               White  United-States       Masters
# 2575            Private               White  United-States          11th
# 2280            Private               White  United-States          11th
# 2259          Local-gov               Black  United-States       HS-grad
# 1236                NaN               Black  United-States       HS-grad
#
#                    status        fam_memb
# 3718   Married-civ-spouse         Husband
# 1298   Married-civ-spouse         Husband
# 3402   Married-civ-spouse         Husband
# 281    Married-civ-spouse         Husband
# 3851              Widowed       Unmarried
# 2222              Widowed       Unmarried
# 2606                  NaN             NaN
# 1987            Separated       Unmarried
# 3947   Married-civ-spouse         Husband
# 956                   NaN             NaN
# 3274             Divorced       Unmarried
# 3024             Divorced       Unmarried
# 918         Never-married       Own-child
# 6           Never-married       Own-child
# 2340   Married-civ-spouse         Husband
# 1791   Married-civ-spouse         Husband
# 636    Married-civ-spouse         Husband
# 1813   Married-civ-spouse         Husband
# 3878   Married-civ-spouse         Husband
# 477                   NaN             NaN
# 3241                  NaN             NaN
# 174         Never-married  Other-relative
# 514         Never-married   Not-in-family
# 2984        Never-married   Not-in-family
# 2540        Never-married       Own-child
# 1277                  NaN             NaN
# 3204   Married-civ-spouse         Husband
# 2779   Married-civ-spouse         Husband
# 294               Widowed   Not-in-family
# 3010              Widowed   Not-in-family
# ...                   ...             ...
# 2267        Never-married       Unmarried
# 2201        Never-married       Unmarried
# 2976   Married-civ-spouse         Husband
# 1554   Married-civ-spouse         Husband
# 3634        Never-married       Own-child
# 84          Never-married       Own-child
# 3441                  NaN             NaN
# 124         Never-married   Not-in-family
# 1856   Married-civ-spouse         Husband
# 3162   Married-civ-spouse         Husband
# 826         Never-married  Other-relative
# 3785        Never-married  Other-relative
# 1961        Never-married   Not-in-family
# 1874        Never-married   Not-in-family
# 2159   Married-civ-spouse         Husband
# 1241                  NaN             NaN
# 2978   Married-civ-spouse         Husband
# 1921   Married-civ-spouse         Husband
# 2999        Never-married   Not-in-family
# 3077        Never-married   Not-in-family
# 2818        Never-married       Own-child
# 3480        Never-married       Own-child
# 2474   Married-civ-spouse         Husband
# 2372   Married-civ-spouse         Husband
# 2423   Married-civ-spouse         Husband
# 1683   Married-civ-spouse         Husband
# 2575        Never-married       Own-child
# 2280        Never-married       Own-child
# 2259             Divorced       Unmarried
# 1236             Divorced       Unmarried
#
# [100 rows x 25 columns]

# %% [markdown]
# Po vypísani duplicitných mien sme zistili, že zlúčením týchto duplikátov vieme vyplniť chýbajúce hodnoty. Zároveň hodnoty, ktoré majú oba duplikáty sú rovnaké.

# %%
dataO=fusionDuplicates(dataO)
dataO
# Out:
#                      name                                            address  \
# 0             Daniel Love        126 Ramirez Roads\r\nNew Jayville, IL 18861
# 1             Roy Paradis  01168 Stark Pine Apt. 583\r\nDavidville, IN 32044
# 2            Charles Chen  09482 Horne Lakes Apt. 373\r\nEast Brian, TN 2...
# 3          Chester Holmes  720 Harris Turnpike Suite 732\r\nEast Sierra, ...
# 4             James Ayala                 Unit 3230 Box 9523\r\nDPO AA 55810
# 3915         Manuel Dupre  216 Elliott Squares\r\nLake Breannaborough, MD...
# 3916          Marcel Ross  33418 Trevino Stravenue Apt. 225\r\nWest Nicho...
# 3917         Mark Macklin  4932 Lauren Mission Suite 711\r\nSouth Danielp...
# 3918         Mike Murdock           842 Scott Road\r\nWest Michael, ND 69887
# 3919              Mike Rm  8317 Sarah Streets Apt. 987\r\nWrighttown, NY ...
# 3920            Paul Ladd                      USNS Townsend\r\nFPO AE 97197
# 3921      Randall Mellett  941 Woods Walks Suite 315\r\nNorth Andrealand,...
# 3922        Raymond Goode     0705 Heather Mountain\r\nFloresmouth, FL 91113
# 3923        Robert Lackey   94782 Ortega Summit\r\nNew Andrewmouth, MN 99751
# 3924      Russell Coleman                 PSC 1977, Box 7638\r\nAPO AE 29246
# 3925     Salvador Donnell  287 Jessica Springs Apt. 923\r\nSantanaton, ND...
# 3926        Steven Jacobs  84245 Williamson Trail\r\nEast Pamelaside, AL ...
# 3927            Tim Price  4811 Raymond Locks Suite 069\r\nEast Michael, ...
# 3928        Virgil Selman  66909 Frederick Path Apt. 504\r\nPort Jennifer...
# 3929       William Glover  655 Cody River Suite 554\r\nNorth Colton, DC 2...
# 3930        William Hicks  66744 Tiffany Shores Apt. 950\r\nNew Timothy, ...
# 3931       William Joecks  089 Sherry Hollow Suite 058\r\nBrianberg, CT 0...
# 3932        William Stone  535 Cabrera Wall Apt. 927\r\nEast David, TX 70904
#
#          kurtosis_oxygen          occupation pregnant  education-num  \
# 0            10.58036423               Sales        f            9.0
# 1            3.713364594        Craft-repair        f            9.0
# 2            6.478064004   Handlers-cleaners        f            9.0
# 3                     ??               Sales        f           10.0
# 4                    NaN    Transport-moving        f            9.0
# 5      6.384963147000001                   ?        f            9.0
# 6            8.938092965               Sales        f           10.0
# 7            5.155939859                   ?        f           12.0
# 8            2.436555082               Sales        f           10.0
# 9            14.38934822               Sales        f            9.0
# 10           8.508906253        Adm-clerical        f            9.0
# 11           10.30903207     Exec-managerial        f           10.0
# 12           8.620895914        Craft-repair        f            9.0
# 13           6.241462914        Craft-repair        f            9.0
# 14          -0.219283809        Craft-repair        f           10.0
# 15           8.520990655     Farming-fishing        f           10.0
# 16           10.64449998       Other-service        f           10.0
# 17           3.870762606   Handlers-cleaners        f            9.0
# 18           7.919433455      Prof-specialty        F           13.0
# 19           5.560734251       Other-service        f           10.0
# 20           9.858380523               Sales        f            9.0
# 21           12.38519299        Tech-support        f           13.0
# 22           12.14303861        Craft-repair        f            9.0
# 23           7.012918477        Craft-repair        f            7.0
# 24            8.02251786      Prof-specialty        f           10.0
# 25          -0.074639079     Exec-managerial    FALSE            9.0
# 26            4.62701081        Adm-clerical        t           10.0
# 27           0.978638555     Exec-managerial        f           11.0
# 28           8.265676186        Craft-repair        f            9.0
# 29    7.6771816039999985               Sales        f            9.0
# ...                  ...                 ...      ...            ...
# 3903         1.582775516      Prof-specialty    FALSE           14.0
# 3904   8.272507037999999   Machine_op_inspct        f           10.0
# 3911            Private               White  United-States       HS-grad
# 3912       Self-emp-inc               White  United-States   Prof-school
# 3913                  ?               White  United-States     Bachelors
# 3914            Private               White  United-States       HS-grad
# 3915       Self-emp-inc                 NaN            NaN            NaN
# 3916   Self-emp-not-inc               White  United-States  Some-college
# 3917            Private               White  United-States     Bachelors
# 3918            Private               Black  United-States     Bachelors
# 3919   Self-emp-not-inc               White  United-States           9th
# 3920            Private               White  United-States       HS-grad
# 3921            Private               White  United-States  Some-college
# 3922   Self-emp-not-inc               White  United-States       HS-grad
# 3923            Private               White  United-States       HS-grad
# 3924            Private               White  United-States     Bachelors
# 3925            Private               White  United-States       Masters
# 3926          State-gov               White  United-States       Masters
# 3927            Private               White  United-States     Bachelors
# 3928            Private               White  United-States          11th
# 3929                NaN               White  United-States       HS-grad
# 3930        Federal-gov               White  United-States       Masters
# 3931            Private               White  United-States          11th
# 3932          Local-gov               Black  United-States       HS-grad
#
#                    status        fam_memb
# 0      Married-civ-spouse         Husband
# 1      Married-civ-spouse         Husband
# 2      Married-civ-spouse         Husband
# 3      Married-civ-spouse         Husband
# 4      Married-civ-spouse         Husband
# 5      Married-civ-spouse       Own-child
# 6                Divorced   Not-in-family
# 7                Divorced       Unmarried
# 8           Never-married       Own-child
# 9           Never-married       Own-child
# 10              Separated       Unmarried
# 11     Married-civ-spouse         Husband
# 12     Married-civ-spouse         Husband
# 13     Married-civ-spouse         Husband
# 14               Divorced   Not-in-family
# 15          Never-married       Own-child
# 16     Married-civ-spouse         Husband
# 17          Never-married   Not-in-family
# 18               Divorced   Not-in-family
# 19     Married-civ-spouse         Husband
# 20     Married-civ-spouse            Wife
# 21     Married-civ-spouse         Husband
# 22               Divorced       Own-child
# 23     Married-civ-spouse         Husband
# 24               Divorced       Unmarried
# 25              Separated   Not-in-family
# 26               Divorced       Unmarried
# 27               Divorced   Not-in-family
# 28          Never-married   Not-in-family
# 29     Married-civ-spouse         Husband
# ...                   ...             ...
# 3903   Married-civ-spouse         Husband
# 3904   Married-civ-spouse         Husband
# 3905   Married-civ-spouse         Husband
# 3906   Married-civ-spouse         Husband
# 3907   Married-civ-spouse         Husband
# 3908        Never-married   Not-in-family
# 3909        Never-married       Own-child
# 3910        Never-married   Not-in-family
# 3911        Never-married  Other-relative
# 3912   Married-civ-spouse         Husband
# 3913   Married-civ-spouse         Husband
# 3914             Divorced       Unmarried
# 3915                  NaN             NaN
# 3916             Divorced       Unmarried
# 3917        Never-married   Not-in-family
# 3918        Never-married       Unmarried
# 3919   Married-civ-spouse         Husband
# 3920        Never-married       Own-child
# 3921        Never-married   Not-in-family
# 3922   Married-civ-spouse         Husband
# 3923        Never-married  Other-relative
# 3924        Never-married   Not-in-family
# 3925   Married-civ-spouse         Husband
# 3926   Married-civ-spouse         Husband
# 3927        Never-married   Not-in-family
# 3928        Never-married       Own-child
# 3929   Married-civ-spouse         Husband
# 3930   Married-civ-spouse         Husband
# 3931        Never-married       Own-child
# 3932             Divorced       Unmarried
#
# [3933 rows x 25 columns]

# %%
sortedO = dataO.sort_values('name')
sortedP = dataP.sort_values('name')

# %%
addressO =sortedO['address']
addressP =sortedP['address']

# %%
np.array_equal(addressO, addressP)
# Out:
# True

# %% [markdown]
# Keďže aj adresy pri menách sú rovnaké tak je jasné, že sa jedna o tie isté osoby a datasety môžeme spojiť na základde mená.

# %%
replaced = dataO.replace(to_replace=r'^[0-9,\-].*[0-9]$',value='number',regex=True)
replaced.select_dtypes(include='object')
# Out:
#                      name                                            address  \
# 0             Daniel Love        126 Ramirez Roads\r\nNew Jayville, IL 18861
# 1             Roy Paradis  01168 Stark Pine Apt. 583\r\nDavidville, IN 32044
# 2            Charles Chen  09482 Horne Lakes Apt. 373\r\nEast Brian, TN 2...
# 3          Chester Holmes  720 Harris Turnpike Suite 732\r\nEast Sierra, ...
# 4             James Ayala                 Unit 3230 Box 9523\r\nDPO AA 55810
# 5           Todd Flanagan  2167 Wells Shoals Apt. 264\r\nEast Brianshire,...
# 6           James Huffman        535 Michael Squares\r\nNorth Sara, ID 61368
# 7           Gary Prentice          055 Nolan Club\r\nWest Bryanton, UT 15308
# 8             Rodger Riis  7719 Frances Drives Apt. 525\r\nWest Brandonst...
# 9         Robert Cabiness  70838 Robbins Camp Suite 853\r\nJacobville, SC...
# 10           John Brehmer        019 Donna Mountains\r\nAlyssaside, NC 78687
# 11           William West  692 Tiffany Cape Suite 776\r\nNew Stacey, OK 9...
# 12        Thomas Rathburn  708 Rodgers Streets Suite 909\r\nVanessamouth,...
# 13           Steven Welch  4017 Christopher Fort Suite 454\r\nHurleyville...
# 14           Leon Fleming  2351 Brian Route Suite 878\r\nPort Richard, SC...
# 15            Jake Pearce  1633 Sanders Club\r\nSouth Timothymouth, LA 30038
# 16            Carl Nelson      680 Higgins Square\r\nSharonborough, NJ 01147
# 17         Brian Murphrey            7682 Cantu Glen\r\nMonroebury, NH 02629
# 18           Brian Orozco  699 Powell Gardens Apt. 171\r\nSloanland, HI 6...
# 19           Julian Davis  75930 Jonathan Passage Suite 688\r\nPort Jamie...
# 20         John Davenport  802 Christian Course Apt. 645\r\nPort Dominiqu...
# 21         Oscar Reynolds           776 Guerrero Lock\r\nLake Erin, NY 53271
# 22       Louis Stallworth          476 Kevin Tunnel\r\nJenniferton, VT 33302
# 23           Harold Hiles           40820 Susan Shore\r\nCoryville, KS 28888
# 24            David Lopez        420 Jensen Place\r\nPort Kyletown, KS 65788
# 25    Kenneth Weatherholt  6644 Marshall Mountains Suite 928\r\nWest Susa...
# 26             Corey Rose   48053 Jeremiah Estate\r\nJeremychester, TN 50588
# 27        Arthur Crandall  806 Matthews River Suite 584\r\nPort Heidiside...
# 28          Jesse Simpson  6825 Lopez Crest Suite 574\r\nLake Sarah, CO 6...
# 29          Rene Kershner  1010 Miles Shore Suite 346\r\nWest Edward, NH ...
# ...                   ...                                                ...
# 3903       Joseph Palumbo   14921 Johnson Stravenue\r\nNorth David, KS 12153
# 3904         Joseph Perez   023 Cook Bypass Apt. 625\r\nNorth Anna, FL 05626
# 3905      Joseph Williams  6558 Smith Park Apt. 719\r\nLake Johnmouth, DE...
# 3906         Juan Thurber  655 Rosales Camp Suite 191\r\nDavisview, WV 49205
# 3907         Kenneth Burr  61596 Danielle Trafficway\r\nSouth Ryan, ND 49582
# 3908       Kenneth Zamora   9086 Becker Streets\r\nNew Michaelbury, MA 54353
# 3909           Kevin Bell  793 Erika Springs Suite 802\r\nLake Donnaview,...
# 3910          Leslie Pack     77641 Brian Camp\r\nSouth Amberville, IA 89230
# 3911       Lonnie Fuhrman      77622 Bright Station\r\nMorrismouth, MO 52269
# 3912       Louis Lochrico      358 Reed Springs\r\nEast Stevenport, NC 86309
# 3913         Luis Salcedo   7232 Mcconnell Prairie\r\nEdwardsmouth, MN 55917
# 3914         Malcolm Rotz  545 Marshall Rapid\r\nEast Stephanieborough, M...
# 3915         Manuel Dupre  216 Elliott Squares\r\nLake Breannaborough, MD...
# 3916          Marcel Ross  33418 Trevino Stravenue Apt. 225\r\nWest Nicho...
# 3917         Mark Macklin  4932 Lauren Mission Suite 711\r\nSouth Danielp...
# 3918         Mike Murdock           842 Scott Road\r\nWest Michael, ND 69887
# 3919              Mike Rm  8317 Sarah Streets Apt. 987\r\nWrighttown, NY ...
# 3920            Paul Ladd                      USNS Townsend\r\nFPO AE 97197
# 3921      Randall Mellett  941 Woods Walks Suite 315\r\nNorth Andrealand,...
# 3922        Raymond Goode     0705 Heather Mountain\r\nFloresmouth, FL 91113
# 3923        Robert Lackey   94782 Ortega Summit\r\nNew Andrewmouth, MN 99751
# 3924      Russell Coleman                 PSC 1977, Box 7638\r\nAPO AE 29246
# 3925     Salvador Donnell  287 Jessica Springs Apt. 923\r\nSantanaton, ND...
# 3926        Steven Jacobs  84245 Williamson Trail\r\nEast Pamelaside, AL ...
# 3927            Tim Price  4811 Raymond Locks Suite 069\r\nEast Michael, ...
# 3928        Virgil Selman  66909 Frederick Path Apt. 504\r\nPort Jennifer...
# 3929       William Glover  655 Cody River Suite 554\r\nNorth Colton, DC 2...
# 3930        William Hicks  66744 Tiffany Shores Apt. 950\r\nNew Timothy, ...
# 3931       William Joecks  089 Sherry Hollow Suite 058\r\nBrianberg, CT 0...
# 3932        William Stone  535 Cabrera Wall Apt. 927\r\nEast David, TX 70904
#
#      kurtosis_oxygen          occupation pregnant  income          workclass  \
# 0             number               Sales        f    >50K            Private
# 1             number        Craft-repair        f   <=50K   Self-emp-not-inc
# 2             number   Handlers-cleaners        f   <=50K            Private
# 3                 ??               Sales        f    >50K            Private
# 4                NaN    Transport-moving        f   <=50K            Private
# 5             number                   ?        f   <=50K                  ?
# 6             number               Sales        f   <=50K            Private
# 7             number                   ?        f   <=50K                  ?
# 8             number               Sales        f   <=50K       Self-emp-inc
# 9             number               Sales        f   <=50K            Private
# 10            number        Adm-clerical        f   <=50K        Federal-gov
# 11            number     Exec-managerial        f    >50K            Private
# 12            number        Craft-repair        f   <=50K            Private
# 13            number        Craft-repair        f   <=50K            Private
# 14            number        Craft-repair        f    >50K            Private
# 15            number     Farming-fishing        f   <=50K          State-gov
# 16            number       Other-service        f   <=50K            Private
# 17            number   Handlers-cleaners        f   <=50K            Private
# 18            number      Prof-specialty        F   <=50K            Private
# 19            number       Other-service        f   <=50K            Private
# 20            number               Sales        f   <=50K            Private
# 21            number        Tech-support        f    >50K            Private
# 22            number        Craft-repair        f   <=50K            Private
# 23            number        Craft-repair        f   <=50K   Self-emp-not-inc
# 24            number      Prof-specialty        f   <=50K            Private
# 25            number     Exec-managerial    FALSE   <=50K        Federal-gov
# 26            number        Adm-clerical        t   <=50K            Private
# 27            number     Exec-managerial        f    >50K            Private
# 28            number        Craft-repair        f   <=50K            Private
# 29            number               Sales        f   <=50K            Private
# ...              ...                 ...      ...     ...                ...
# 3903          number      Prof-specialty    FALSE    >50K          Local-gov
# 3904          number   Machine_op_inspct        f   <=50K            Private
# 3905          number        Craft-repair        F    >50K            Private
# 3906          number      Prof-specialty        f    >50K        Federal-gov
# 3907             NaN      Prof-specialty        f    >50K   Self-emp-not-inc
# 3908          number    Transport-moving        f    >50K            Private
# 3909          number        Adm_clerical        f   <=50K                NaN
# 3910          number   Machine-op-inspct        f   <=50K            Private
# 3911             NaN       Other-service        f   <=50K            Private
# 3912          number      Prof-specialty        f    >50K       Self-emp-inc
# 3913          number                   ?        f   <=50K                  ?
# 3914          number   Machine-op-inspct        f   <=50K            Private
# 3915             NaN               Sales        f    >50K       Self-emp-inc
# 3916          number        Craft-repair        f   <=50K   Self-emp-not-inc
# 3917             NaN        Adm-clerical        f   <=50K            Private
# 3918             NaN               Sales        f    >50K            Private
# 3919          number    Transport-moving        f    >50K   Self-emp-not-inc
# 3920          number               Sales        f   <=50K            Private
# 3921          number               Sales        f   <=50K            Private
# 3922          number        Craft_repair        f   <=50K   Self-emp-not-inc
# 3923          number       Other-service        f   <=50K            Private
# 3924          number               Sales        f   <=50K            Private
# 3925          number      Prof-specialty    FALSE    >50K            Private
# 3926          number      Prof-specialty        f   <=50K          State-gov
# 3927          number      Prof-specialty        t    >50K            Private
# 3928             NaN               Sales        f   <=50K            Private
# 3929          number               Sales        f   <=50K                NaN
# 3930          number      Prof-specialty        f   <=50K        Federal-gov
# 3931              ??       Other-service        f   <=50K            Private
# 3932             NaN        Adm-clerical        f   <=50K          Local-gov
#
#                     ethn          state            edu               status  \
# 0                  White  United-States       HS-grad    Married-civ-spouse
# 1                  White  United-States       HS-grad    Married-civ-spouse
# 2                  White  United-States       HS-grad    Married-civ-spouse
# 3                  White  United-States  Some-college    Married-civ-spouse
# 4     Amer-Indian-Eskimo  United-States       HS-grad    Married-civ-spouse
# 5                  White  United-States       HS-grad    Married-civ-spouse
# 6                  White  United-States  Some-college              Divorced
# 7                  White  United-States    Assoc-acdm              Divorced
# 8                  White  United-States  Some-college         Never-married
# 9                  White  United-States       HS-grad         Never-married
# ...              ...
# 3903         Husband
# 3904         Husband
# 3905         Husband
# 3906         Husband
# 3907         Husband
# 3908   Not-in-family
# 3909       Own-child
# 3910   Not-in-family
# 3911  Other-relative
# 3912         Husband
# 3913         Husband
# 3914       Unmarried
# 3915             NaN
# 3916       Unmarried
# 3917   Not-in-family
# 3918       Unmarried
# 3919         Husband
# 3920       Own-child
# 3921   Not-in-family
# 3922         Husband
# 3923  Other-relative
# 3924   Not-in-family
# 3925         Husband
# 3926         Husband
# 3927   Not-in-family
# 3928       Own-child
# 3929         Husband
# 3930         Husband
# 3931       Own-child
# 3932       Unmarried
#
# [3933 rows x 12 columns]

# %%
replaced['kurtosis_oxygen'].unique()
# Out:
# array(['number', '??', nan], dtype=object)

# %%
replaced['occupation'].unique()
# Out:
# array([' Sales', ' Craft-repair', ' Handlers-cleaners',
#        ' Transport-moving', ' ?', ' Adm-clerical', ' Exec-managerial',
#        ' Farming-fishing', ' Other-service', ' Prof-specialty',
#        ' Tech-support', ' Machine-op-inspct', ' Exec_managerial',
#        ' Other_service', ' Prof_specialty', ' Protective-serv',
#        ' Craft_repair', ' Protective_serv', ' Adm_clerical',
#        ' Machine_op_inspct', ' Farming_fishing', ' Priv-house-serv',
#        ' Transport_moving', ' Handlers_cleaners', ' Priv_house_serv',
#        ' Tech_support', ' Armed-Forces'], dtype=object)

# %%
replaced['pregnant'].unique()
# Out:
# array(['f', 'F', 'FALSE', 't', 'TRUE', 'T'], dtype=object)

# %%
replaced['education-num'].unique()
# Out:
# array([ 9., 10., 12., 13.,  7., 11., 14., 16.,  8.,  6.,  3., 15.,  4.,
#         5.,  2.,  1.])

# %%
replaced['edu'].unique()
# Out:
# array(['HS-grad ', 'Some-college ', 'Assoc-acdm ', 'Bachelors ', '11th ',
#        'Assoc-voc ', 'Masters ', 'Doctorate ', '12th ', '10th ',
#        '5th-6th ', 'Prof-school ', '7th-8th ', '9th ', '1st-4th ',
#        'Preschool ', nan], dtype=object)

# %%
replaced['income'].unique()
# Out:
# array([' >50K', ' <=50K', nan], dtype=object)

# %%
replaced['workclass'].unique()
# Out:
# array([' Private', ' Self-emp-not-inc', ' ?', ' Self-emp-inc',
#        ' Federal-gov', ' State-gov', ' Local-gov', ' Without-pay', nan],
#       dtype=object)

# %%
replaced['ethn'].unique()
# Out:
# array(['White', 'Amer-Indian-Eskimo', 'Black', 'Asian-Pac-Islander',
#        'Other', nan], dtype=object)

# %%
replaced['state'].unique()
# Out:
# array(['United-States', 'India', 'Thailand', 'Puerto-Rico', 'Philippines',
#        'Cuba', '?', 'China', 'Columbia', 'Canada', 'Poland', 'Mexico',
#        'Vietnam', 'El-Salvador', 'Jamaica', 'Japan', 'Yugoslavia',
#        'Italy', 'Germany', 'Guatemala', 'Ecuador', 'Hungary', 'Ireland',
#        'Taiwan', 'England', 'France', 'Peru', 'Portugal', 'South',
#        'Trinadad&Tobago', 'Dominican-Republic', 'Iran', 'Cambodia',
#        'Outlying-US(Guam-USVI-etc)', 'Haiti', 'Scotland', 'Nicaragua',
#        'Hong', 'Holand-Netherlands', 'Greece', nan], dtype=object)

# %%
replaced['status'].unique()
# Out:
# array([' Married-civ-spouse', ' Divorced', ' Never-married', ' Separated',
#        ' Widowed', ' Married-spouse-absent', ' Married-AF-spouse', nan],
#       dtype=object)

# %%
replaced['fam_memb'].unique()
# Out:
# array(['Husband', 'Own-child', 'Not-in-family', 'Unmarried', 'Wife',
#        'Other-relative', nan], dtype=object)

# %% [markdown]
# Nahradením čisel a vypísaním unikátnych hodnôt sme zistili, že prázdne hodnoty sú označené buď dvoma, jedným otáznikom alebo slovom nan. Tieto hodnoty nahradíme jednotným np.nan. A taktiež prevedieme zjednotenie totožných gramatický rozdielných hodnôt, o ktorých sme vedeli už z analýzy.

# %%
correctValuesO(dataO)

# %%
dataO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3933 entries, 0 to 3932
# Data columns (total 25 columns):
# name                3933 non-null object
# address             3933 non-null object
# kurtosis_oxygen     3539 non-null object
# occupation          3733 non-null object
# pregnant            3933 non-null object
# education-num       3933 non-null float64
# skewness_glucose    3933 non-null float64
# mean_glucose        3539 non-null float64
# std_oxygen          3933 non-null float64
# capital-gain        3933 non-null float64
# skewness_oxygen     3933 non-null float64
# kurtosis_glucose    3933 non-null float64
# fnlwgt              3933 non-null float64
# class               3933 non-null float64
# std_glucose         3932 non-null float64
# income              3932 non-null object
# mean_oxygen         3933 non-null float64
# hours-per-week      3932 non-null float64
# capital-loss        3933 non-null float64
# workclass           3731 non-null object
# ethn                3932 non-null object
# state               3857 non-null object
# edu                 3932 non-null object
# status              3932 non-null object
# fam_memb            3932 non-null object
# dtypes: float64(13), object(12)
# memory usage: 768.2+ KB

# %%
dataO['pregnant'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %%
replaced = dataP.replace(to_replace = r'[0-9]', value = 'x', regex = True)

# %%
replaced["date_of_birth"].unique()
# Out:
# array(['xxxx-xx-xx', 'xx-xx-xx', 'xx/xx/xxxx', 'xxxx-xx-xx xx:xx:xx',
#        'xxxx-xx-xx xx xx xx', 'xxxx/xx/xx'], dtype=object)

# %% [markdown]
# xx/xx/xxxx --> dd/mm/yyyy

# %%
date = dataP["date_of_birth"][dataP["date_of_birth"].str.match(r'[0-9][0-9]/[0-9][0-9]/[0-9][0-9][0-9][0-9]')].sort_values(ascending=False).str.split("/", 3, expand = True)

# %%
date.max()
# Out:
# 0      31.0
# 1      12.0
# 2    2005.0
# dtype: float64

# %% [markdown]
# xxxx/xx/xx --> yyyy/mm/dd

# %%
date = dataP["date_of_birth"][dataP["date_of_birth"].str.match(r'[0-9][0-9][0-9][0-9]/[0-9][0-9]/[0-9][0-9]')].sort_values(ascending=False).str.split("/", 3, expand = True)

# %%
date.max()
# Out:
# 0    2020.0
# 1      12.0
# 2      31.0
# dtype: float64

# %% [markdown]
# xxxx-xx-xx --> yyyy-mm-dd

# %%
date = dataP["date_of_birth"][dataP["date_of_birth"].str.match(r'[0-9][0-9][0-9][0-9]-[0-9][0-9]-[0-9][0-9]')].sort_values(ascending=False).str.split("-", 3, expand = True)

# %%
date.max()
# Out:
# 0           2016
# 1             12
# 2    31 00:00:00
# dtype: object

# %% [markdown]
# xx-xx-xx --> yy-mm-dd

# %%
date = dataP["date_of_birth"][dataP["date_of_birth"].str.match(r'[0-9][0-9]-[0-9][0-9]-[0-9][0-9]')].sort_values(ascending=False).str.split("-", 3, expand = True)

# %%
date.max()
# Out:
# 0    96.0
# 1    12.0
# 2    31.0
# dtype: float64

# %%
date[0].unique()
# Out:
# array(['96', '93', '91', '90', '89', '88', '87', '86', '85', '84', '83',
#        '82', '81', '80', '79', '78', '77', '76', '75', '74', '73', '72',
#        '71', '70', '69', '68', '67', '66', '65', '64', '63', '62', '61',
#        '60', '59', '58', '57', '56', '55', '54', '53', '52', '51', '50',
#        '49', '48', '47', '42', '39', '29', '03', '00'], dtype=object)

# %% [markdown]
# Teraz, keď poznáme všetky formáty dátumu a usporiadanie mesiacov a dní môžeme ich zjednotiť.

# %%
correctValuesP(dataP)
# Out:
# C:\Users\adria\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
replaced = dataP.replace(to_replace = r'[0-9]', value = 'x', regex = True)
replaced['date_of_birth'].unique()
# Out:
# array(['xxxx-xx-xx'], dtype=object)

# %%
dataF = fusionDatasets(dataP, dataO)

# %%
dataF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3933 entries, 0 to 3932
# Data columns (total 26 columns):
# age                 3933 non-null int64
# sex                 3933 non-null object
# date_of_birth       3933 non-null object
# kurtosis_oxygen     3539 non-null object
# occupation          3733 non-null object
# pregnant            3933 non-null object
# education-num       3933 non-null float64
# skewness_glucose    3933 non-null float64
# mean_glucose        3539 non-null float64
# std_oxygen          3933 non-null float64
# capital-gain        3933 non-null float64
# skewness_oxygen     3933 non-null float64
# kurtosis_glucose    3933 non-null float64
# fnlwgt              3933 non-null float64
# class               3933 non-null float64
# std_glucose         3932 non-null float64
# income              3932 non-null object
# mean_oxygen         3933 non-null float64
# hours-per-week      3932 non-null float64
# capital-loss        3933 non-null float64
# workclass           3731 non-null object
# ethn                3932 non-null object
# state               3857 non-null object
# edu                 3932 non-null object
# status              3932 non-null object
# fam_memb            3932 non-null object
# dtypes: float64(13), int64(1), object(12)
# memory usage: 829.6+ KB

# %%
dataF = dataF.astype({'class':str,"education-num":str,"kurtosis_oxygen":float})
dataF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3933 entries, 0 to 3932
# Data columns (total 26 columns):
# age                 3933 non-null int64
# sex                 3933 non-null object
# date_of_birth       3933 non-null object
# kurtosis_oxygen     3539 non-null float64
# occupation          3733 non-null object
# pregnant            3933 non-null object
# education-num       3933 non-null object
# skewness_glucose    3933 non-null float64
# mean_glucose        3539 non-null float64
# std_oxygen          3933 non-null float64
# capital-gain        3933 non-null float64
# skewness_oxygen     3933 non-null float64
# kurtosis_glucose    3933 non-null float64
# fnlwgt              3933 non-null float64
# class               3933 non-null object
# std_glucose         3932 non-null float64
# income              3932 non-null object
# mean_oxygen         3933 non-null float64
# hours-per-week      3932 non-null float64
# capital-loss        3933 non-null float64
# workclass           3731 non-null object
# ethn                3932 non-null object
# state               3857 non-null object
# edu                 3932 non-null object
# status              3932 non-null object
# fam_memb            3932 non-null object
# dtypes: float64(12), int64(1), object(13)
# memory usage: 829.6+ KB

# %% [markdown]
# Vychýlené hodnoty pri veku poznáme z úvdnej analýzy. A vieme, že majú rozdelenie ako dáta mimo vychýlených hodnôt. Po prezretí vychýlených hodnôt sme zistili, že sú to buď 100 alebo -100 násobky bezných hodnôt. A preto ich takto upravíme.

# %%
correctAge(dataF)
# Out:
# C:\Users\adria\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
dataF['age'].unique()

# %%
replaced = dataF[['capital-gain', 'capital-loss']].replace(to_replace=[0.0,99999.0],value = np.nan)
replaced.hist()

# %% [markdown]
# Pre tieto dva stlpce nebudeme odstranovat outlierov pretoze by sme prisli o tieto namerane hodnoty.

# %%
detectReplaceOutliers(dataF)

# %%
dataF.describe()

# %% [markdown]
# Na stĺpce kde chýba málo hodnôt sme sa rozhodli použit nahradenie nulových hodnôt mediánom, kedže sa tam nachádza aj vek a počet odpracovaných hodín a priemer by bol desatíne číslo.

# %%
impMeanFit(dataF)
imp.statistics_

# %%
setKategNaNtoUnknown(dataF)

# %%
dataF.info()

# %% [markdown]
# Z analýzy vieme, že nižšie vykreslené atribúty majú najbližšie k linearnemu grafu pre dané atribúty a preto ich použijeme pri lineárnej regresii.

# %%
sns.pairplot(dataF,y_vars=["skewness_glucose", "kurtosis_glucose"], x_vars="mean_glucose")

# %%
sns.pairplot(dataF,y_vars=["skewness_oxygen", "mean_oxygen"], x_vars=["kurtosis_oxygen"])

# %%
linearFit(dataF)

# %%
linearKurtOx.coef_

# %%
linearMeanGlu.coef_

# %%
pred = linearKurtOx.predict(dataF[["skewness_oxygen","mean_oxygen"]])

# %%
plt.scatter(dataF["skewness_oxygen"], dataF["kurtosis_oxygen"],  color='gray')
plt.plot(dataF["skewness_oxygen"], pred, color='red', linewidth=2)
plt.show()

# %%
predG = linearMeanGlu.predict(dataF[["skewness_glucose", "kurtosis_glucose"]])

# %%
plt.scatter(dataF["kurtosis_glucose"], dataF["mean_glucose"],  color='gray')
plt.plot(dataF["kurtosis_glucose"], predG, color='red', linewidth=2)
plt.show()

# %%
linearTransform(dataF)

# %%
dataF.info()

# %%
dataF.describe()

# %%
dataF.describe(exclude=np.number)

# %% [markdown]
# <h2>TEST</h2>

# %%
dataPer = pd.read_csv("personal_train.csv", index_col=0)
dataOth = pd.read_csv("other_train.csv", index_col=0)

# %%
dataFin = finalTransform(dataPer,dataOth)

# %%
dataFin.info()

# %%
dataFin.describe()

# %% [markdown]
# <h2> Záver </h2>

# %% [markdown]
# Výsledkom predpracovania sú dve funkcie:<br>
#     finalFitAndTransform(dataP,dataO), ktorá sa spúšťa nad trenovacími dátami, kde upraví hodnoty, zjednoti datasety, upraví outlierov a doplní chýbajúce hodnoty.<br>
#     finalTransform(dataP,dataO), ktorá sa spúšťa po predchadzajúcej ale nad testovacými dátami.<br>
#     Obydve funkcie vracajú predspracovaný dataset.
